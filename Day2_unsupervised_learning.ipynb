# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris, fetch_openml
from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import confusion_matrix

# %%
#Loading of the data
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names

# Standardizing the features so they are on the same scale
X_std = StandardScaler().fit_transform(X)

# %%
pca = PCA(n_components=4)
X_pca = pca.fit_transform(X_std)

# Plotting the results of PCA
plt.figure(figsize=(8, 6))
for i, target_name in zip([0, 1, 2, 3], iris.target_names):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], label=target_name)
plt.legend()
plt.title('PCA of IRIS dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
# The variance ratio of the principal components
explained_variance_ratio = pca.explained_variance_ratio_
explained_variance_ratio
# Out:
# array([0.72962445, 0.22850762, 0.03668922, 0.00517871])

# %%
# Creating a bar chart to visualize the explained variance by each principal component
components = ['PC1', 'PC2', 'PC3', 'PC4']
explained_variance = explained_variance_ratio * 100  # Convert to percentage

plt.figure(figsize=(8, 6))
plt.bar(components, explained_variance, color='skyblue')
plt.xlabel('Principal Components')
plt.ylabel('Variance Explained (%)')
plt.title('Variance Explained by Each Principal Component - Iris Dataset')
plt.show()

# %%
# Apply PCA to the Iris dataset to identify the top 2 principal components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
# Number of clusters
n_clusters = 2

# Apply K-means clustering
kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=42)
clusters = kmeans.fit_predict(X)

print(f"Inertia: {kmeans.inertia_}")
silhouette_avg = silhouette_score(X, clusters)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 152.3479517603579
# Silhouette Score: 0.6810461692117462

# %%
# Plotting
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', alpha=0.7)
plt.title('Clusters plotted on top of the first two Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.show()

# %%
conf_matrix = confusion_matrix(y, clusters)
conf_matrix
# Out:
# array([[ 0, 50,  0],
#        [47,  3,  0],
#        [50,  0,  0]])

# %%
# Number of clusters
n_clusters = 3

# Apply K-means clustering
kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=42)
clusters = kmeans.fit_predict(X)
print(f"Inertia: {kmeans.inertia_}")
silhouette_avg = silhouette_score(X, clusters)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 78.851441426146
# Silhouette Score: 0.5528190123564095

# %%
# Plotting
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', alpha=0.7)
plt.title('Clusters plotted on top of the first two Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.show()

# %%
conf_matrix = confusion_matrix(y, clusters)
conf_matrix
# Out:
# array([[ 0, 50,  0],
#        [48,  0,  2],
#        [14,  0, 36]])

# %%
# Number of clusters
n_clusters = 4

# Apply K-means clustering
kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=42)
clusters = kmeans.fit_predict(X)
print(f"Inertia: {kmeans.inertia_}")
silhouette_avg = silhouette_score(X, clusters)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 57.22847321428572
# Silhouette Score: 0.49805050499728737

# %%
# Plotting
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', alpha=0.7)
plt.title('Clusters plotted on top of the first two Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.show()

# %%
conf_matrix = confusion_matrix(y, clusters)
conf_matrix
# Out:
# array([[50,  0,  0,  0],
#        [ 0, 23,  0, 27],
#        [ 0, 17, 32,  1],
#        [ 0,  0,  0,  0]])

# %%
# Apply PCA to the Iris dataset to identify the top 2 principal components
pca = PCA(n_components=4)
X_pca = pca.fit_transform(X_std)

# %%
# Plotting on the 2nd and 3rd Principal Components
plt.figure(figsize=(8, 6))
for i, target_name in zip([0, 1, 2], iris.target_names):
    plt.scatter(X_pca[y == i, 1], X_pca[y == i, 2], label=target_name)
plt.legend()
plt.title('Scatter plot of the 2nd and 3rd Principal Components')
plt.xlabel('Principal Component 2')
plt.ylabel('Principal Component 3')
plt.show()

# %%
# Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(X)
print(f"Inertia: {kmeans.inertia_}")
silhouette_avg = silhouette_score(X, clusters)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 57.22847321428572
# Silhouette Score: 0.48603419703456857

# %%
# Plotting
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', alpha=0.7)
plt.title('Clusters plotted on top of the first two Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.show()

# %%
conf_matrix = confusion_matrix(y, clusters)
conf_matrix
# Out:
# array([[ 0,  0,  0,  0],
#        [ 1, 49,  0,  0],
#        [ 6,  0, 44,  0],
#        [10,  0, 40,  0]])

# %%
# Apply DBSCAN
dbscan = DBSCAN(eps =.2, min_samples=5)
clusters = dbscan.fit_predict(X)
print(f"Inertia: {kmeans.inertia_}")
silhouette_avg = silhouette_score(X, clusters)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 57.22847321428572
# Silhouette Score: 0.1825642832387007

# %%
# Plotting
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', alpha=0.7)
plt.title('Clusters plotted on top of the first two Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.show()

# %%
conf_matrix = confusion_matrix(y, clusters)
conf_matrix
# Out:
# array([[50,  0,  0],
#        [ 0, 50,  0],
#        [ 0, 50,  0]])

# %%
# Apply DBSCAN
dbscan = DBSCAN(eps=0.6, min_samples=3)
clusters = dbscan.fit_predict(X)
print(f"Inertia: {kmeans.inertia_}")
silhouette_avg = silhouette_score(X, clusters)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 57.22847321428572
# Silhouette Score: 0.423002591790791

# %%
# Plotting
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', alpha=0.7)
plt.title('Clusters plotted on top of the first two Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.show()

# %%
conf_matrix = confusion_matrix(y, clusters)
conf_matrix
# Out:
# array([[ 0,  0,  0,  0],
#        [ 1, 49,  0,  0],
#        [ 0,  0, 46,  4],
#        [ 4,  0, 46,  0]])

# %%
#This finds out the the eps and min_sample value for a give cluster number by DBScan clustering

# Initialize variables to store the best parameters
best_eps = 0.5
best_min_samples = 5
best_n_clusters = 0
best_silhouette_score = -1

# Parameter sweep
for eps in np.arange(0.1, 1.0, 0.1):
    for min_samples in range(2, 10):
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        clusters = dbscan.fit_predict(X_std)
        n_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)

        # Compute silhouette score only if more than 1 cluster and less noise
        if n_clusters > 1 and list(clusters).count(-1) < len(X) * 0.5:
            silhouette_avg = silhouette_score(X_std, clusters)
            if n_clusters == 4 and silhouette_avg > best_silhouette_score:
                best_eps = eps
                best_min_samples = min_samples
                best_n_clusters = n_clusters
                best_silhouette_score = silhouette_avg

best_eps, best_min_samples, best_n_clusters, best_silhouette_score
# Out:
# (0.6, 3, 4, 0.29516241784322833)

# %%
# Number of clusters
n_clusters = 2

# Apply K-means clustering
kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=42)
y_kmeans = kmeans.fit_predict(X)
print(f"Inertia: {kmeans.inertia_}")
silhouette_avg = silhouette_score(X, y_kmeans)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 152.3479517603579
# Silhouette Score: 0.6810461692117462

# %%
# Plotting the 1st and 2nd Principal Components as they are the top two PCs
plt.figure(figsize=(8, 6))
for i, target_name in zip([0, 1, 2], iris.target_names):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], label=target_name)
plt.legend()
plt.title('Scatter plot of the 1st and 2nd Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
tsne = TSNE(n_components=2, random_state=0, perplexity = 20 )
X_tsne = tsne.fit_transform(X_std)

# Plotting the results of t-SNE
plt.figure(figsize=(8, 6))
for i, target_name in zip([0, 1, 2], iris.target_names):
    plt.scatter(X_tsne[y == i, 0], X_tsne[y == i, 1], label=target_name)
plt.legend()
plt.title('t-SNE visualization of IRIS dataset')
plt.xlabel('t-SNE axis 1')
plt.ylabel('t-SNE axis 2')
plt.show()

# %%
print(f"Explained Variance Ratio: {pca.explained_variance_ratio_}")
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762 0.03668922 0.00517871]

# %%
# Load the MNIST dataset
mnist = fetch_openml('mnist_784', version=1)

# Use only a subset for quicker execution
X = mnist.data[:3000]
y = mnist.target[:3000]

X_std = StandardScaler().fit_transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
pca = PCA(n_components=50)
X_pca = pca.fit_transform(X_std)

# %%
pca_full = PCA()
X_pca_full = pca_full.fit_transform(X_std)

# Calculate the variance explained by each component
explained_variance = pca_full.explained_variance_ratio_

# Generate the scree plot
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o', linestyle='--')
plt.title('Scree Plot for MNIST PCA')
plt.xlabel('Number of Components')
plt.ylabel('Variance Explained')
plt.show()

# %%
# Number of clusters
n_clusters = 10

# Apply K-means clustering
kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=42)
y_kmeans = kmeans.fit_predict(X_std)

# %%
print(f"Inertia: {kmeans.inertia_}")
silhouette_avg = silhouette_score(X, y_kmeans)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 1604564.7961955527
# Silhouette Score: 0.06824694794742148

# %%
# Reduce the dimensionality for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
import pandas as pd
import seaborn as sns

# Create a DataFrame with true labels and assigned cluster labels
df = pd.DataFrame({'true_labels': y.astype(int), 'cluster_labels': y_kmeans})

# Create a cross-tabulation
ct = pd.crosstab(df['true_labels'], df['cluster_labels'])

plt.figure(figsize=(10, 8))
sns.heatmap(ct, annot=True, fmt='d', cmap='Blues')
plt.title('Cross-tabulation of True Digits and Cluster Assignments')
plt.xlabel('Cluster Label')
plt.ylabel('True Label')
plt.show()

# %%
# # Apply DBSCAN
# dbscan = DBSCAN(eps=5, min_samples=5)
# y_dbscan = dbscan.fit_predict(X)

# %%
# Standardize and reduce dimensionality
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# K-means clustering
kmeans = KMeans(n_clusters=10, random_state=42)
labels_kmeans = kmeans.fit_predict(X_pca)

# DBSCAN clustering
dbscan = DBSCAN(eps=0.7, min_samples=30)
labels_dbscan = dbscan.fit_predict(X_pca)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Set up plot
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# K-means clusters
axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=labels_kmeans, cmap='viridis', s=50, alpha=0.5)
axes[0].set_title('K-means Clustering')
axes[0].set_xlabel('PCA Component 1')
axes[0].set_ylabel('PCA Component 2')

# DBSCAN clusters
axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=labels_dbscan, cmap='viridis', s=50, alpha=0.5)
axes[1].set_title('DBSCAN Clustering')
axes[1].set_xlabel('PCA Component 1')
axes[1].set_ylabel('PCA Component 2')

# Show plots
plt.show()

# %%
tsne = TSNE(n_components=2, random_state=0)
X_tsne = tsne.fit_transform(X_std)

# %%
# Set up plot
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# K-means clusters
axes[0].scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels_kmeans, cmap='viridis', s=50, alpha=0.5)
axes[0].set_title('K-means Clustering')
axes[0].set_xlabel('tSNE Component 1')
axes[0].set_ylabel('tSNE Component 2')

# DBSCAN clusters
axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=labels_dbscan, cmap='viridis', s=50, alpha=0.5)
axes[1].set_title('DBSCAN Clustering')
axes[1].set_xlabel('tSNE Component 1')
axes[1].set_ylabel('tSNE Component 2')

# Show plots
plt.show()

# %%
# # Project the centroids into the same PCA-reduced space
# centers_reduced = pca.transform(kmeans.cluster_centers_)
# plt.figure(figsize=(10, 8))

# # Scatter plot of the digits with colors representing clusters
# colors = plt.cm.tab10(np.arange(10))
# for i in range(10):
#     plt.scatter(X_pca[y_kmeans == i, 0], X_pca[y_kmeans == i, 1], s=8, color=colors[i], label=f'Cluster {i}', alpha=0.5)

# # Plot the centroids
# plt.scatter(centers_reduced[:, 0], centers_reduced[:, 1], s=100, marker='X', color='black', label='Centroids')
# plt.legend()
# plt.title('K-means Clustering of MNIST with PCA-reduced Data')
# plt.xlabel('PCA Component 1')
# plt.ylabel('PCA Component 2')
# plt.show()

# %%
#do the above thing for iris
#Loading of the data
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names

# Standardizing the features so they are on the same scale
X_std = StandardScaler().fit_transform(X)

# K-means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
labels_kmeans = kmeans.fit_predict(X_std)

# DBSCAN clustering
dbscan = DBSCAN(eps=0.9, min_samples=6)
labels_dbscan = dbscan.fit_predict(X_std)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
# Set up plot
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# K-means clusters
axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=labels_kmeans, cmap='viridis', s=50, alpha=0.5)
axes[0].set_title('K-means Clustering')
axes[0].set_xlabel('PCA Component 1')
axes[0].set_ylabel('PCA Component 2')

# DBSCAN clusters
axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=labels_dbscan, cmap='viridis', s=50, alpha=0.5)
axes[1].set_title('DBSCAN Clustering')
axes[1].set_xlabel('PCA Component 1')
axes[1].set_ylabel('PCA Component 2')

# Show plots
plt.show()

# %%
#generate tSNE for 2D visualisation
tsne = TSNE(n_components=2, random_state=0)
X_tsne = tsne.fit_transform(X_std)

# %%
# Set up plot
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# K-means clusters
axes[0].scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels_kmeans, cmap='viridis', s=50, alpha=0.5)
axes[0].set_title('K-means Clustering')
axes[0].set_xlabel('tSNE Component 1')
axes[0].set_ylabel('tSNE Component 2')

# DBSCAN clusters
axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=labels_dbscan, cmap='viridis', s=50, alpha=0.5)
axes[1].set_title('DBSCAN Clustering')
axes[1].set_xlabel('tSNE Component 1')
axes[1].set_ylabel('tSNE Component 2')

# Show plots
plt.show()
